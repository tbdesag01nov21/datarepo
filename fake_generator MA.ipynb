# %%
# IMPORTS
import numpy as np
import pandas as pd

from faker import Faker

# %%
# FUNCS
# For quick empty list assignment
def mklist(n):
    for i in range(n):
        yield []
        
# To easily add every data to the correct list
def item_to_lists(item, lists):
    for i in range(len(item)):
        lists[i].append(item[i])
        
    return lists

# To easily add every data to the correct list
def dict_to_lists(item, names, lists):
    for name, empty_list in zip(names, lists):
        if name in item.keys():
            empty_list.append(item.get(name))
            
        elif name not in item.keys():
            empty_list.append(0)
            
    return None

# %%
# To generate a fake user
def generate_fake_user(min_age, max_age):
    # Nacionalidad
    nations_list = ['es_ES', 'es_CA',
                    'pt_PT', 'en_GB',
                    'fr_FR', 'de_DE',
                    'it_IT', 'nl_NL']
    u_nation = np.random.choice(nations_list, p=[0.58, 0.12, 0.04, 0.06, 0.04, 0.08, 0.03, 0.05])
    
    # Género
    genders = ['hombre', 'mujer', 'otro']
    u_gender = np.random.choice(genders, p=[0.425, 0.525, 0.05])
    
    # Nombre e inicial
    if u_gender == 'hombre':
        u_name = fk[u_nation].first_name_male()
    if u_gender == 'mujer':
        u_name = fk[u_nation].first_name_female()
    if u_gender == 'otro':
        u_name = fk[u_nation].first_name_nonbinary()
    
    u_last_name = fk[u_nation].last_name()
    
    # Idiomas
    if u_nation == 'es_ES':
        u_lang = np.random.choice(['Castellano', 'Euskara', 'Galego'], p=[0.55, 0.25, 0.20])
        u_last_name_2 = fk[u_nation].last_name()
    elif u_nation == 'es_CA':
        u_lang = 'Català'
        u_last_name_2 = fk[u_nation].last_name()
    elif u_nation == 'pt_PT':
        u_lang = 'Português'
        u_last_name_2 = fk[u_nation].last_name()
    elif u_nation == 'en_GB':
        u_lang = 'English'
        u_last_name_2 = ''
    elif u_nation == 'fr_FR':
        u_lang = 'Français'
        u_last_name_2 = ''
    elif u_nation == 'de_DE':
        u_lang = 'Deutsche'
        u_last_name_2 = ''
    elif u_nation == 'it_IT':
        u_lang = 'Italiano'
        u_last_name_2 = ''
    else:
        u_lang = 'Nederlandse'
        u_last_name_2 = ''
        
    u_full_name = f'{u_name} {u_last_name} {u_last_name_2}'
    
    # u_initial = f"{u_name[0]}. {u_last_name[0]}."
    
    # Mail
    u_mail_company = fk.ascii_free_email()
    u_mail = u_name.lower() + '_' + u_last_name.lower() + '@' + u_mail_company.split('@')[1]  # TODO ¡CUIDADO! si hay doble nombre, deja el espacio ¿PONER DIFERENTES FORMAS?
    
    # Dirección
    u_direc = fk['es_ES'].street_address()
    
    # Provincia y CCAA
    country = {'Andalucía': ['Almería', 'Cádiz', 'Córdoba', 'Granada', 'Huelva', 'Jaén', 'Málaga', 'Sevilla'],
               'Aragón': ['Huesca', 'Teruel', 'Zaragoza'],
               'Principado de Asturias': ['Asturias'],
               'Islas Baleares': ['Islas Baleares'],
               'Canarias': ['Las Palmas', 'Santa Cruz de Tenerife'],
               'Cantabria': ['Cantabria'],
               'Castilla y León': ['Ávila', 'Burgos', 'León', 'Palencia', 'Salamanca', 'Segovia', 'Soria', 'Valladolid', 'Zamora'],
               'Castilla-La Mancha': ['Albacete', 'Ciudad Real', 'Cuenca', 'Guadalajara', 'Toledo'],
               'Cataluña': ['Barcelona', 'Gerona', 'Lérida', 'Tarragona'],
               'Comunidad Valenciana': ['Alicante', 'Castellón', 'Valencia'],
               'Extremadura': ['Badajoz', 'Cáceres'],
               'Galicia': ['La Coruña', 'Lugo', 'Orense', 'Pontevedra'],
               'Comunidad de Madrid': ['Madrid'],
               'Región de Murcia': ['Murcia'],
               'Comunidad Foral de Navarra': ['Navarra'],
               'País Vasco': ['Álava', 'Vizcaya', 'Guipúzcoa'],
               'La Rioja': ['La Rioja'],
               'Ciudad Autónoma de Ceuta': ['Ceuta'],
               'Ciudad Autónoma de Melilla': ['Melilla']}
    
    zipcode = {'Almería': '04', 'Cádiz': '11', 'Córdoba': '14', 'Granada': '18', 'Huelva': '21', 'Jaén': '23', 'Málaga': '29', 'Sevilla': '41', 
               'Huesca': '22', 'Teruel': '44', 'Zaragoza': '50', 
               'Asturias': '33', 
               'Islas Baleares': '07', 
               'Las Palmas': '35', 'Santa Cruz de Tenerife': '38', 
               'Cantabria': '39', 
               'Ávila': '50', 'Burgos': '09', 'León': '24', 'Palencia': '34', 'Salamanca': '37', 'Segovia': '40', 'Soria': '42', 'Valladolid': '47', 'Zamora': '49', 
               'Albacete': '02', 'Ciudad Real': '13', 'Cuenca': '16', 'Guadalajara': '19', 'Toledo': '45', 
               'Barcelona': '08', 'Gerona': '17', 'Lérida': '25', 'Tarragona': '43', 
               'Alicante': '03', 'Castellón': '12', 'Valencia': '46', 
               'Badajoz': '06', 'Cáceres': '10', 
               'La Coruña': '15', 'Lugo': '27', 'Orense': '32', 'Pontevedra': '36', 
               'Madrid': '28', 
               'Murcia': '30', 
               'Navarra': '31', 
               'Álava': '01', 'Vizcaya': '48', 'Guipúzcoa': '20', 
               'La Rioja': '26', 
               'Ceuta': '51', 
               'Melilla': '52'}

    u_ccaa = np.random.choice(list(country.keys()))
    u_prov = np.random.choice(country[u_ccaa])
    u_zipc = zipcode.get(u_prov) + str(np.random.randint(9)) + str(np.random.randint(9)) + str(np.random.randint(9))
    
    # Teléfono
    u_phone = str(fk['es_ES'].phone_number()).replace(' ', '')
    
    # Id
    # Generada desde fuera de la función
    
    ##########
    # FIN DE DATOS GENERALES
    # u_name
    # u_full_name
    # u_mail
    # u_direc
    # u_prov
    # u_zipc
    # u_phone
    # u_id (generada fuera)
    ##########
    
    # Age
    u_years = np.random.gamma(3, 6)
    while u_years < 60 or u_years >= 99:
        u_years = np.random.gamma(3, 6)
        u_years_pron = np.random.randint (1, 999)
        if u_years_pron in range (1, 4):
            u_years = np.random.randint (100, 116)
        
    u_years = int(u_years)
    u_age = fk.date_of_birth(None, u_years, u_years)
    #u_age = f"{u_age.year}-{u_age.month}-{u_age.day}"
    u_age = f"{u_age.day}-{u_age.month}-{u_age.year}"
    
    # TODO - Añadir fecha de nacimiento

    
    # Proximidad
    proximity = ['misma provincia', 'misma comunidad', 'todo el país']
    
    u_prox = np.random.choice(proximity, p=[0.6, 0.3, 0.1])
    
    # Sector
    sector = ['sanidad', 'investigaciontecnica', 'ingenieria', 'musica', 'forestal', 'seguridad', 'administrativo', 'rh', 'artes', 'comunicacion', 'cine', 'derecho', 'amacasa', 'empresariales', 'mantenimiento', 'enseñanza', 'construccion', 'investigacioncientifica', 'otro']
    u_sector = np.random.choice(sector)
    
    
    # Colectivo LGTB
    orientation = ['no acepto', 'acepto']
    u_lgtb = np.random.choice(orientation, p=[0.65, 0.35])
    
    # Miembros unidad familiar
    group = ['Individual', 'Grupo', 'Familia']
    u_family = np.random.choice(group)
    # TODO - Generar con distribución tras saber bien que se busca
    
    # Religión
    religion = ['no acepto', 'acepto']
    u_relig = np.random.choice(religion, p=[0.6, 0.4])
    
    politic = ['no acepto', 'acepto']
    u_politic = np.random.choice(politic, p=[0.6, 0.4])
    
    # Veganismo
    veganism = ['Común', 'Vegetariano', 'Vegano']
    u_vegan = np.random.choice(veganism, p=[0.7, 0.20, 0.10])
    
    # Mascotas
    pets = ['no acepto', 'acepto']
    u_pets = np.random.choice(pets, p=[0.6, 0.4])
    
    # Fumador
    smoker = ['no acepto', 'acepto']
    u_smoke = np.random.choice(smoker, p=[0.5, 0.5])
    
    # Entorno
    locations = ['interior', 'costa', 'montaña']
    
    u_env = np.random.choice(locations)

    # Rango edad para compartir q busca
    age_range = ['50-60', '60-70', '70-80', '+80']
    
    u_range = np.random.choice(age_range)
    
    # Presupuesto
    price_list = [300, 400, 500,
                  600, 700,
                  800, 900, 1000, 1100,
                  1200, 1300, 1400, 1500]
    
    u_budget = np.random.choice(price_list, p=[0.1, 0.1, 0.1,
                                               0.15, 0.15,
                                               0.05, 0.05, 0.05, 0.05,
                                               0.05, 0.05, 0.05, 0.05])
    
    # Superficie
    size = [50, 100, 150, 200, 250, 300, 350, 400, 450, 500,
            550, 600, 650, 700, 750, 800, 850, 900, 950, 1000]

    u_sqr_m = np.random.choice(size)
    
    # Aseo
    washroom = ['compartido', 'privado']
    
    u_bath = np.random.choice(washroom, p=[0.35, 0.65])
    
    # Zonas exteriores
    negative_choice = fk.boolean(chance_of_getting_true=75)
    
    if negative_choice == False:
        u_outs = ['no']
    
    else:
        outside = ['jardin', 'terraza', 'piscina']
        
        choices = np.random.randint(1, len(outside)+1)
        u_outs = np.random.choice(outside, size=choices, replace=False)
    
    # Instalaciones
    negative_choice = fk.boolean(chance_of_getting_true=90)
    
    if negative_choice == False:
        u_facil = []
        
    else:
        facilities = ['salacine', 'golf', 'recreativos', 'spa', 'hipica', 'esqui',
                      'salamanualidades', 'pingpong', 'gimnasio', 'billar', 'futbolin',
                      'rehabilitacion', 'padel', 'baloncesto', 'garage', 'cocina',
                      'buffet', 'lavavajillas', 'lavanderia', 'zonasverdes', 'tenis',
                      'piscina', 'huerto', 'cubierta', 'barbacoa', 'futbol', 'trastero']
            
        choices = np.random.randint(1, len(facilities)+1)
        u_facil = np.random.choice(facilities, size=choices, replace=False)
    
    # Carnet de conducir
    license = [False, True]
    
    u_drive = np.random.choice(license, p=[0.25, 0.75])
    
    # Tamaño comunidad
    cohabitants = ['<3', '<6', '<9', '+10']
    
    u_max_p = np.random.choice(cohabitants, p=[0.30, 0.30, 0.25, 0.15])

    # Aficiones
    hobbies = ['accion', 'activo', 'ajedrez', 'alegre', 'alternativa',
               'amable', 'animales', 'antiguedades', 'apasionado', 'arte',
               'artesanias', 'astrologia', 'astronomia', 'atento', 'aventura',
               'aventurero', 'aves', 'badminton', 'bailarin', 'baile',
               'baloncesto', 'beatboxing', 'beisbol', 'belico', 'bingo',
               'biologia', 'blogging', 'blues', 'bolero', 'bolillo',
               'bolos', 'bordado', 'boxeo', 'bricolage', 'buceo',
               'calmado', 'cantante', 'canto', 'carpinteria', 'cartas',
               'casino', 'caza', 'ceramica', 'cerveza', 'ciclismo',
               'cienciaficcion', 'cine', 'cinefilo', 'clasica', 'cocina',
               'colaborador', 'comedia', 'comics', 'comprador', 'conciertos',
               'copla', 'corazon', 'correr', 'cosplay', 'costura',
               'creativo', 'crimen', 'croche', 'crossfit', 'crucigramas',
               'cultura', 'dardos', 'decidido', 'deportista', 'dibujo',
               'disfraces', 'divertido', 'documental', 'drama', 'electronica',
               'empatico', 'emprendedor', 'entustiasta', 'escritura', 'esqui',
               'excursionismo', 'excursionista', 'familiar', 'fantasia', 'fiestero',
               'filatelia', 'filologia', 'fisica', 'flamenco', 'flexible',
               'folk', 'foodie', 'fotografia', 'fotografo', 'fronton',
               'fumadores', 'futbol', 'gamer', 'ganchillo', 'gastronomia',
               'generoso', 'gimnasio', 'golf', 'gospel', 'gracioso',
               'hipica', 'historia', 'historica', 'hogar', 'honesto',
               'iglesia', 'india', 'instrumental', 'instrumentos', 'jardineria',
               'jazz', 'latina', 'libros', 'literatura', 'lounge',
               'macrame', 'madrugador', 'magia', 'manualidades', 'matematicas',
               'meditacion', 'mediterranea', 'mesa', 'metal', 'mexicana', 
               'misterio', 'moda', 'modelismo', 'montanismo', 'motociclismo',
               'museos', 'musica', 'musical', 'natacion', 'negro',
               'nocturno', 'numismatica', 'opera', 'optimista', 'ordenado',
               'oriental', 'pachangueo', 'padel', 'pesca', 'petanca',
               'pintura', 'piraguismo', 'playa', 'poesia', 'poker',
               'politica', 'practico', 'proactivo', 'punk', 'puntocruz',
               'quimica', 'rb', 'reciclaje', 'reggae', 'relajado',
               'remo', 'reposteria', 'robotica', 'rock', 'rol',
               'romantica', 'rompecabezas', 'saludable', 'sensato', 'sociable',
               'socializar', 'soul', 'suspense', 'tarot', 'teatro',
               'tecnologia', 'tejido', 'telenovelas', 'tenis', 'tenismesa',
               'terror', 'trabajo', 'tratofacil', 'turismo', 'vegano',
               'vegetariano', 'viajar', 'viajero', 'videojuegos', 'vino',
               'vivo', 'voluntariado', 'western', 'yeye', 'yoga',
               'zarzuela', 'zoologia']
    # TODO - Separar en aficiones y personalidad??
    
    hobbies_num = np.random.randint(15, (len(hobbies)/2)+1)
    hobbies = list(np.random.choice(hobbies, hobbies_num, replace=False))
    hobbies_values = list(np.random.randint(1, 6, hobbies_num))

    u_hobbies = {k:v for k, v in zip(hobbies, hobbies_values)}
    
    # Unificación de características del usuario
    user = [u_name, u_last_name, u_last_name_2, u_initial, u_years,
            u_gender, u_sector, u_ccaa, u_prov, u_prox,
            u_phone, u_mail, u_lang, u_lgtb, u_family,
            u_relig, u_politic, u_vegan, u_pets, u_smoke,
            u_env, u_range, u_budget, u_sqr_m, u_bath,
            u_outs, u_facil, u_drive, u_max_p]
    
    return user, u_hobbies

# %%
# Instance faker object
locale_dict = ['es_ES',
               'es_CA',
               'pt_PT',
               'en_GB',
               'fr_FR',
               'de_DE',
               'it_IT',
               'nl_NL']

fk = Faker(locale_dict)

# %%
# Build aux objects
# Empty lists
users_name, users_last_name, users_last_name_2, users_initial = mklist(4)
users_years, users_gender, users_sector, users_ccaa = mklist(4)
users_prov, users_prox, users_phone, users_mail = mklist(4)
users_lang, users_lgtb, users_family, users_relig = mklist(4)
users_politic, users_vegan, users_pets, users_smoke = mklist(4)
users_env, users_range, users_budget, users_sqr_m = mklist(4)
users_bath, users_outs, users_facil, users_drive = mklist(4)
users_max_p = []

# List of lists
user_lists = [users_name, users_last_name, users_last_name_2, users_initial,
              users_years, users_gender, users_sector, users_ccaa,
              users_prov, users_prox, users_phone, users_mail,
              users_lang, users_lgtb, users_family, users_relig,
              users_politic, users_vegan, users_pets, users_smoke,
              users_env, users_range, users_budget, users_sqr_m,
              users_bath, users_outs, users_facil, users_drive,
              users_max_p]

# Empty lists
accion, activo, ajedrez, alegre, alternativa = mklist(5)
amable, animales, antiguedades, apasionado, arte = mklist(5)
artesanias, astrologia, astronomia, atento, aventura = mklist(5)
aventurero, aves, badminton, bailarin, baile = mklist(5)
baloncesto, beatboxing, beisbol, belico, bingo = mklist(5)
biologia, blogging, blues, bolero, bolillo = mklist(5)
bolos, bordado, boxeo, bricolage, buceo = mklist(5)
calmado, cantante, canto, carpinteria, cartas = mklist(5)
casino, caza, ceramica, cerveza, ciclismo = mklist(5)
cienciaficcion, cine, cinefilo, clasica, cocina = mklist(5)
colaborador, comedia, comics, comprador, conciertos = mklist(5)
copla, corazon, correr, cosplay, costura = mklist(5)
creativo, crimen, croche, crossfit, crucigramas = mklist(5)
cultura, dardos, decidido, deportista, dibujo = mklist(5)
disfraces, divertido, documental, drama, electronica = mklist(5)
empatico, emprendedor, entustiasta, escritura, esqui = mklist(5)
excursionismo, excursionista, familiar, fantasia, fiestero = mklist(5)
filatelia, filologia, fisica, flamenco, flexible = mklist(5)
folk, foodie, fotografia, fotografo, fronton = mklist(5)
fumadores, futbol, gamer, ganchillo, gastronomia = mklist(5)
generoso, gimnasio, golf, gospel, gracioso = mklist(5)
hipica, historia, historica, hogar, honesto = mklist(5)
iglesia, india, instrumental, instrumentos, jardineria = mklist(5)
jazz, latina, libros, literatura, lounge = mklist(5)
macrame, madrugador, magia, manualidades, matematicas = mklist(5)
meditacion, mediterranea, mesa, metal, mexicana, = mklist(5)
misterio, moda, modelismo, montanismo, motociclismo = mklist(5)
museos, musica, musical, natacion, negro = mklist(5)
nocturno, numismatica, opera, optimista, ordenado = mklist(5)
oriental, pachangueo, padel, pesca, petanca = mklist(5)
pintura, piraguismo, playa, poesia, poker = mklist(5)
politica, practico, proactivo, punk, puntocruz = mklist(5)
quimica, rb, reciclaje, reggae, relajado = mklist(5)
remo, reposteria, robotica, rock, rol = mklist(5)
romantica, rompecabezas, saludable, sensato, sociable = mklist(5)
socializar, soul, suspense, tarot, teatro = mklist(5)
tecnologia, tejido, telenovelas, tenis, tenismesa = mklist(5)
terror, trabajo, tratofacil, turismo, vegano = mklist(5)
vegetariano, viajar, viajero, videojuegos, vino = mklist(5)
vivo, voluntariado, western, yeye, yoga = mklist(5)
zarzuela, zoologia = mklist(2)

# List of lists
hobbies_lists = [accion, activo, ajedrez, alegre, alternativa,
                 amable, animales, antiguedades, apasionado, arte,
                 artesanias, astrologia, astronomia, atento, aventura,
                 aventurero, aves, badminton, bailarin, baile,
                 baloncesto, beatboxing, beisbol, belico, bingo,
                 biologia, blogging, blues, bolero, bolillo,
                 bolos, bordado, boxeo, bricolage, buceo,
                 calmado, cantante, canto, carpinteria, cartas,
                 casino, caza, ceramica, cerveza, ciclismo,
                 cienciaficcion, cine, cinefilo, clasica, cocina,
                 colaborador, comedia, comics, comprador, conciertos,
                 copla, corazon, correr, cosplay, costura,
                 creativo, crimen, croche, crossfit, crucigramas,
                 cultura, dardos, decidido, deportista, dibujo,
                 disfraces, divertido, documental, drama, electronica,
                 empatico, emprendedor, entustiasta, escritura, esqui,
                 excursionismo, excursionista, familiar, fantasia, fiestero,
                 filatelia, filologia, fisica, flamenco, flexible,
                 folk, foodie, fotografia, fotografo, fronton,
                 fumadores, futbol, gamer, ganchillo, gastronomia,
                 generoso, gimnasio, golf, gospel, gracioso,
                 hipica, historia, historica, hogar, honesto,
                 iglesia, india, instrumental, instrumentos, jardineria,
                 jazz, latina, libros, literatura, lounge,
                 macrame, madrugador, magia, manualidades, matematicas,
                 meditacion, mediterranea, mesa, metal, mexicana, 
                 misterio, moda, modelismo, montanismo, motociclismo,
                 museos, musica, musical, natacion, negro,
                 nocturno, numismatica, opera, optimista, ordenado,
                 oriental, pachangueo, padel, pesca, petanca,
                 pintura, piraguismo, playa, poesia, poker,
                 politica, practico, proactivo, punk, puntocruz,
                 quimica, rb, reciclaje, reggae, relajado,
                 remo, reposteria, robotica, rock, rol,
                 romantica, rompecabezas, saludable, sensato, sociable,
                 socializar, soul, suspense, tarot, teatro,
                 tecnologia, tejido, telenovelas, tenis, tenismesa,
                 terror, trabajo, tratofacil, turismo, vegano,
                 vegetariano, viajar, viajero, videojuegos, vino,
                 vivo, voluntariado, western, yeye, yoga,
                 zarzuela, zoologia]

# List of names
hobbies_names = ['accion', 'activo', 'ajedrez', 'alegre', 'alternativa',
                 'amable', 'animales', 'antiguedades', 'apasionado', 'arte',
                 'artesanias', 'astrologia', 'astronomia', 'atento', 'aventura',
                 'aventurero', 'aves', 'badminton', 'bailarin', 'baile',
                 'baloncesto', 'beatboxing', 'beisbol', 'belico', 'bingo',
                 'biologia', 'blogging', 'blues', 'bolero', 'bolillo',
                 'bolos', 'bordado', 'boxeo', 'bricolage', 'buceo',
                 'calmado', 'cantante', 'canto', 'carpinteria', 'cartas',
                 'casino', 'caza', 'ceramica', 'cerveza', 'ciclismo',
                 'cienciaficcion', 'cine', 'cinefilo', 'clasica', 'cocina',
                 'colaborador', 'comedia', 'comics', 'comprador', 'conciertos',
                 'copla', 'corazon', 'correr', 'cosplay', 'costura',
                 'creativo', 'crimen', 'croche', 'crossfit', 'crucigramas',
                 'cultura', 'dardos', 'decidido', 'deportista', 'dibujo',
                 'disfraces', 'divertido', 'documental', 'drama', 'electronica',
                 'empatico', 'emprendedor', 'entustiasta', 'escritura', 'esqui',
                 'excursionismo', 'excursionista', 'familiar', 'fantasia', 'fiestero',
                 'filatelia', 'filologia', 'fisica', 'flamenco', 'flexible',
                 'folk', 'foodie', 'fotografia', 'fotografo', 'fronton',
                 'fumadores', 'futbol', 'gamer', 'ganchillo', 'gastronomia',
                 'generoso', 'gimnasio', 'golf', 'gospel', 'gracioso',
                 'hipica', 'historia', 'historica', 'hogar', 'honesto',
                 'iglesia', 'india', 'instrumental', 'instrumentos', 'jardineria',
                 'jazz', 'latina', 'libros', 'literatura', 'lounge',
                 'macrame', 'madrugador', 'magia', 'manualidades', 'matematicas',
                 'meditacion', 'mediterranea', 'mesa', 'metal', 'mexicana', 
                 'misterio', 'moda', 'modelismo', 'montanismo', 'motociclismo',
                 'museos', 'musica', 'musical', 'natacion', 'negro',
                 'nocturno', 'numismatica', 'opera', 'optimista', 'ordenado',
                 'oriental', 'pachangueo', 'padel', 'pesca', 'petanca',
                 'pintura', 'piraguismo', 'playa', 'poesia', 'poker',
                 'politica', 'practico', 'proactivo', 'punk', 'puntocruz',
                 'quimica', 'rb', 'reciclaje', 'reggae', 'relajado',
                 'remo', 'reposteria', 'robotica', 'rock', 'rol',
                 'romantica', 'rompecabezas', 'saludable', 'sensato', 'sociable',
                 'socializar', 'soul', 'suspense', 'tarot', 'teatro',
                 'tecnologia', 'tejido', 'telenovelas', 'tenis', 'tenismesa',
                 'terror', 'trabajo', 'tratofacil', 'turismo', 'vegano',
                 'vegetariano', 'viajar', 'viajero', 'videojuegos', 'vino',
                 'vivo', 'voluntariado', 'western', 'yeye', 'yoga',
                 'zarzuela', 'zoologia']

# %%
# Generate users
users_to_create = 10

for i in range(users_to_create):
    user, hobbies = generate_fake_user(60, 115)
    item_to_lists(user, user_lists)
    dict_to_lists(hobbies, hobbies_names, hobbies_lists)

# %%
# Create users_id list
users_id = [i for i in range(1, len(user_lists[-1])+1)]

# %%
# Build aux objects
# List of lists
users_lists = [users_id, users_name, users_last_name, users_last_name_2,
               users_initial, users_years, users_gender, users_sector, 
               users_ccaa, users_prov, users_prox, users_phone, 
               users_mail, users_lang, users_lgtb, users_family, 
               users_relig, users_politic, users_vegan, users_pets, 
               users_smoke, users_env, users_range, users_budget, 
               users_sqr_m, users_bath, users_outs, users_facil, 
               users_drive, users_max_p]

# List of names
users_names = ['users_id', 'users_name', 'users_last_name', 'users_last_name_2',
               'users_initial', 'users_years', 'users_gender', 'users_sector', 
               'users_ccaa', 'users_prov', 'users_prox', 'users_phone', 
               'users_mail', 'users_lang', 'users_lgtb', 'users_family', 
               'users_relig', 'users_politic', 'users_vegan', 'users_pets', 
               'users_smoke', 'users_env', 'users_range', 'users_budget', 
               'users_sqr_m', 'users_bath', 'users_outs', 'users_facil', 
               'users_drive', 'users_max_p']

# %%
# Turn data into dataframe
fake_users = {k: v for k, v in zip(users_names, users_lists)}
fake_hobbies = {k: v for k, v in zip(hobbies_names, hobbies_lists)}

fake_data = pd.DataFrame(fake_users | fake_hobbies)

# %%
# Show DataFrame to check for errors
fake_data
# Out:
#    users_id    users_name users_last_name users_last_name_2 users_initial  \
# 0         1       Roberta          Rincón           Beltran         R. R.
# 1         2         Heimo        Herrmann              None         H. H.
# 2         3     Mechthild        Bolander              None         M. B.
# 3         4  José Antonio          Ibañez              Sola         J. I.
# 4         5       Luciana           Lledó             Navas         L. L.
# 5         6      Nathalie        Pasquier              None         N. P.
# 6         7          Kike          Bayona             Plana         K. B.
# 7         8         Dierk            Mude              None         D. M.
# 8         9     Esperanza          Zapata            Mendez         E. Z.
# 9        10       Suzanne           Leroy              None         S. L.
#
#    users_years users_gender             users_sector  \
# 0           61        mujer                   musica
# ...

# %%
# Save dataframe as csv
# fake_data.to_csv(f'./fake_users_{users_to_create}_users.csv', encoding='utf-8')

# %% [markdown]
# ___
# # A PARTIR DE AQUI SON NOTAS DE FER Y MA

# %%
f'Hej! {None}'
# Out:
# 'Hej! None'

# %%
# {
#   "nombre": "Juan",
#   "apellidos": "Sanchez Rodriguez",
#   "email": "guillem@guillem.com",
#   "direccion": "Calle Mayor 48",
#   "ciudad": "Sevilla",
#   "cp": "28154",
#   "telefono": "611520515",
#   "id_usuario": 15
# }

# %%
{
  "aficiones": [
    "activo: 1",
    "deportista: 2",
    "calmado: 3",
    "atento: 4",
    "alegre: 5",
    "colaborador: 4",
    "creativo: 4",
    "decidido: 4",
    "tratofacil: 3",
    "empatico: 3",
    "entustiasta: 3",
    "flexible: 4",
    "amable: 4",
    "divertido: 4",
    "honesto: 4",
    "gracioso: 4",
    "optimista: 4",
    "ordenado: 4",
    "apasionado: 4",
    "practico: 5",
    "proactivo: 5",
    "sensato: 5",
    "relajado: 5",
    "sociable: 5",
    "generoso: 5",
    "alternativa: 5",
    "blues: 4",
    "clasica: 4",
    "electronica: 3",
    "folk: 4",
    "gospel: 3",
    "instrumental: 3",
    "jazz: 4",
    "latina: 3",
    "alternativa: 3",
    "blues: 4",
    "clasica: 4",
    "electronica: 3",
    "folk: 4",
    "gospel: 4",
    "instrumental: 3",
    "jazz: 4",
    "latina: 4",
    "lounge: 4",
    "metal: 4",
    "opera: 4",
    "punk: 4",
    "rb: 4",
    "reggae: 4",
    "rock: 5",
    "soul: 5",
    "copla: 5",
    "pachangueo: 4",
    "yeye: 5",
    "bolero: 5",
    "zarzuela: 5",
    "flamenco: 5",
    "accion: 5",
    "aventura: 5",
    "comedia: 4",
    "documental: 4",
    "drama: 4",
    "crimen: 4",
    "negro: 3",
    "fantasia: 4",
    "historia: 4",
    "terror: 4",
    "misterio: 4",
    "politica: 4",
    "romantica: 4",
    "cienciaficcion: 3",
    "suspense: 4",
    "musical: 4",
    "belico: 4",
    "western: 4",
    "badminton: 5",
    "beisbol: 5",
    "boxeo: 5",
    "baloncesto: 4",
    "bolos: 3",
    "piraguismo: 4",
    "buceo: 5",
    "futbol: 5",
    "crossfit: 5",
    "ciclismo: 5",
    "golf: 5",
    "gimnasio: 2",
    "excursionismo: 4",
    "hipica: 5",
    "padel: 5",
    "remo: 5",
    "correr: 4",
    "esqui: 4",
    "fronton: 3",
    "natacion: 3",
    "tenismesa: 2",
    "tenis: 3",
    "ajedrez: 3",
    "motociclismo: 2",
    "petanca: 3",
    "caza: 4",
    "yoga: 4",
    "pesca: 4",
    "playa: 1",
    "aves: 1",
    "jardineria: 3",
    "montanismo: 3",
    "manualidades: 3",
    "artesanias: 4",
    "tejido: 4",
    "croche: 4",
    "ganchillo: 4",
    "macrame: 4",
    "bordado: 4",
    "puntocruz: 3",
    "bolillo: 4",
    "ceramica: 4",
    "modelismo: 4",
    "carpinteria: 4",
    "costura: 4",
    "bricolage: 4",
    "robotica: 4",
    "cerveza: 2",
    "cocina: 4",
    "reposteria: 4",
    "gastronomia: 2",
    "india: 4",
    "oriental: 4",
    "mexicana: 4",
    "mediterranea: 4",
    "museos: 3",
    "escritura: 3",
    "beatboxing: 3",
    "componermusica: 2",
    "baile: 4",
    "fotografia: 4",
    "dibujo: 3",
    "instrumentos: 2",
    "canto: 5",
    "conciertos: 4",
    "teatro: 5",
    "opera: 5",
    "pintura: 5",
    "literatura: 5",
    "poesia: 4",
    "comics: 4",
    "blogging: 4",
    "cine: 5",
    "mesa: 2",
    "dardos: 4",
    "crucigramas: 3",
    "cartas: 3",
    "rompecabezas: 3",
    "poker: 4",
    "videojuegos: 3",
    "bingo: 4",
    "casino: 4",
    "magia: 4",
    "telenovelas: 3",
    "reciclaje: 3",
    "iglesia: 2",
    "socializar: 4",
    "voluntariado: 3",
    "animales: 4",
    "astrologia: 4",
    "tarot: 4",
    "meditacion: 4",
    "corazon: 3",
    "viajar: 3",
    "vino: 3",
    "cosplay: 4",
    "disfraces: 4",
    "turismo: 4",
    "rol: 3",
    "vivo: 5",
    "historica: 4",
    "fumadores: 4",
    "antiguedades: 3",
    "filatelia: 4",
    "numismatica: 4",
    "astronomia: 3",
    "historia: 4",
    "matematicas: 3",
    "fisica: 4",
    "quimica: 4",
    "filologia: 4",
    "biologia: 5",
    "zoologia: 5"
  ],
  "apellidos": "Sanchez Rodriguez",
  "carnet": true,
  "ciudad": "Sevilla",
  "cp": "28154",
  "dinero": "1300",
  "direccion": "Calle Mayor 48",
  "edad": 60,
  "email": "guillem@guillem.com",
  "exteriores": [
    "jardin",
    "no",
    "terraza",
    "baloncesto",
    "huerto",
    "barbacoa",
    "padel",
    "tenis",
    "piscina",
    "cubierta",
    "futbol",
    "golf",
    "hipica",
    "esqui"
  ],
  "fumador": true,
  "genero": "hombre",
  "gente": "4",
  "id_usuario": 15,
  "idiomas": [
    "castellano",
    "catalan",
    "euskera",
    "gallego",
    "valenciano",
    "coreano",
    "chino",
    "japones",
    "ingles",
    "italiano",
    "aleman",
    "frances",
    "ruso",
    "neerlandes"
  ],
  "instalaciones": [
    "salacine",
    "recreativos",
    "salamanualidades",
    "gimnasio",
    "rehabilitacion",
    "pingpong",
    "spa",
    "billar",
    "futbolin",
    "trastero",
    "garage",
    "cocina",
    "buffet",
    "lavavajillas",
    "lavanderia"
  ],
  "lavabo": "privado",
  "mascotas": false,
  "metros": "800",
  "nombre": "Juan",
  "oficio": [
    "sanidad",
    "ingenieria",
    "forestal",
    "administrativo",
    "artes",
    "comunicacion",
    "derecho",
    "empresariales",
    "enseñanza",
    "investigacioncientifica",
    "investigaciontecnica",
    "musica",
    "seguridad",
    "rh",
    "cine",
    "amacasa",
    "mantenimiento",
    "construccion",
    "otro"
  ],
  "orientacionSexual": false,
  "politica": true,
  "rangoEdad": [
    "50-60",
    "60-70",
    "70-80",
    "+80"
  ],
  "region": [
    "andalucia",
    "aragon",
    "asturias",
    "baleares",
    "canarias",
    "cantabria",
    "castillalamancha",
    "castillaleon",
    "cataluña",
    "valencia",
    "extremadura",
    "galicia",
    "madrid",
    "murcia",
    "navarra",
    "paisvasco",
    "rioja",
    "ceuta",
    "melilla"
  ],
  "religion": false,
  "telefono": "611520515",
  "tipoVivienda": "duplex",
  "ubicacion": "interior"
}
