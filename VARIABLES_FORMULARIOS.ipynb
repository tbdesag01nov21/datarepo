# %% [markdown]
# # Columnas matriz recomendador

# %% [markdown]
# ## Tenemos que pensar qué hacer con columnas con valores categóricos

# %%
lista_variables_login = { "Usuario ID" : int,
                        "Nombre usuario" : str, # no afecta recomendador
                        "Apellidos usuario" : str, # no afecta recomendador
                        "Email usuario" : str, # no afecta recomendador
                        "Direccion usuario" : str, # no afecta recomendador
                        "Ciudad usuario" : str,
                        "Codigo postal usuario": str,
                        "Telefono usuario" : str, # no afecta recomendador
                        "Password usuario" : str # no afecta recomendador
}

lista_variables_perfil = {  "Edad usuario" : int,
                            "Genero usuario" : [0, 1, 2], # 0 = masculino 1 = femenino 2 = otros ¿qué hacemos con el género? lo dejamos fuera del recomendador?
                            "Oficio usuario" : ["Sanitario", "Ingeniero", "Agrario-forestal", "Administrativo", "Artes", "Comunicación", "Derecho", 
                                                "Empresariales / económicas", "Enseñanza", "Investigación científica", "Investigación técnica", "Música",
                                                "Protección y seguridad", "Recursos humanos", "Cine y teatro", "Ama de casa", "Mantenimiento", "Construcción", 
                                                "Otra profesión"],
                            "Idioma usuario" : ["Inglés", "Francés", "Castellano", "Chino", "Japonés", "Alemán", "Italiano", "Ruso", "Holandés", "Coreano",
                                                "Gallego", "Catalán", "Euskera", "Valenciano"],
                            "Abierto a comunidad LGTBIQ+" : [0, 1], # 0=no 1=si
                            "Abierto a diferentes religiones" : [0, 1], # 0=no 1=si
                            "Abierto a diferentes ideologias politicas" : [0, 1], # 0=no 1=si
                            "Tipo de alimentacion" : ["omnívora", "vegetariana", "vegana"],
                            "Mascota usuario" : [0, 1], # 0=no 1=si
                            "Fumador usuario" : [0, 1, 2], #0=Bajo ningún concepto 1=Indiferente 2=Abierto
                            # carácter (24 variables):
                            "Activo" : [0, 1, 2, 3, 4, 5],
                            "Calmado" : [0, 1, 2, 3, 4, 5],
                            "Atento" : [0, 1, 2, 3, 4, 5],
                            "Alegre" : [0, 1, 2, 3, 4, 5],
                            "Colaborador" : [0, 1, 2, 3, 4, 5],
                            "Creativo" : [0, 1, 2, 3, 4, 5],
                            "Decidido" : [0, 1, 2, 3, 4, 5],
                            "De trato fácil" : [0, 1, 2, 3, 4, 5],
                            "Empático" : [0, 1, 2, 3, 4, 5],
                            "Entusiasta" : [0, 1, 2, 3, 4, 5],
                            "Flexible" : [0, 1, 2, 3, 4, 5],
                            "Amable" : [0, 1, 2, 3, 4, 5],
                            "Divertido" : [0, 1, 2, 3, 4, 5],
                            "Honesto" : [0, 1, 2, 3, 4, 5],
                            "Gracioso" : [0, 1, 2, 3, 4, 5],
                            "Optimista" : [0, 1, 2, 3, 4, 5],
                            "Ordenado" : [0, 1, 2, 3, 4, 5],
                            "Apasionado" : [0, 1, 2, 3, 4, 5],
                            "Práctico" : [0, 1, 2, 3, 4, 5],
                            "Proactivo" : [0, 1, 2, 3, 4, 5],
                            "Sensato" : [0, 1, 2, 3, 4, 5],
                            "Relajado" : [0, 1, 2, 3, 4, 5],
                            "Sociable" : [0, 1, 2, 3, 4, 5],
                            "Generoso" : [0, 1, 2, 3, 4, 5],
                            # música (24 variables):
                            "Música alternativa" : [0, 1, 2, 3, 4, 5],
                            "Blues" : [0, 1, 2, 3, 4, 5],
                            "Clásica" : [0, 1, 2, 3, 4, 5],
                            "Electrónica" : [0, 1, 2, 3, 4, 5],
                            "Folk" : [0, 1, 2, 3, 4, 5],
                            "Gospel" : [0, 1, 2, 3, 4, 5],
                            "Instrumental" : [0, 1, 2, 3, 4, 5],
                            "Jazz" : [0, 1, 2, 3, 4, 5],
                            "Latina" : [0, 1, 2, 3, 4, 5],
                            "Lounge" : [0, 1, 2, 3, 4, 5],
                            "Metal" : [0, 1, 2, 3, 4, 5],
                            "Ópera" : [0, 1, 2, 3, 4, 5],
                            "Pop" : [0, 1, 2, 3, 4, 5],
                            "Punk" : [0, 1, 2, 3, 4, 5],
                            "R&B" : [0, 1, 2, 3, 4, 5],
                            "Reggae" : [0, 1, 2, 3, 4, 5],
                            "Rock" : [0, 1, 2, 3, 4, 5],
                            "Soul" : [0, 1, 2, 3, 4, 5],
                            "Copla" : [0, 1, 2, 3, 4, 5],
                            "Pachangueo" : [0, 1, 2, 3, 4, 5],
                            "Ye-yé" : [0, 1, 2, 3, 4, 5],
                            "Bolero" : [0, 1, 2, 3, 4, 5],
                            "Zarzuela" : [0, 1, 2, 3, 4, 5],
                            "Flamenco" : [0, 1, 2, 3, 4, 5],
                            # deportes (28 variables):
                            "Bádminton" : [0, 1, 2, 3, 4, 5],
                            "Jugar a los bolos" : [0, 1, 2, 3, 4, 5],
                            "Boxeo" : [0, 1, 2, 3, 4, 5],
                            "Béisbol" : [0, 1, 2, 3, 4, 5],
                            "Piragüismo" : [0, 1, 2, 3, 4, 5],
                            "Buceo" : [0, 1, 2, 3, 4, 5],
                            "Fútbol" : [0, 1, 2, 3, 4, 5],
                            "Golf" : [0, 1, 2, 3, 4, 5],
                            "Excursionismo" : [0, 1, 2, 3, 4, 5],
                            "Gimnasio" : [0, 1, 2, 3, 4, 5],
                            "Montar a caballo" : [0, 1, 2, 3, 4, 5],
                            "Pádel" : [0, 1, 2, 3, 4, 5],
                            "Remo" : [0, 1, 2, 3, 4, 5],
                            "Correr" : [0, 1, 2, 3, 4, 5],
                            "Esquí" : [0, 1, 2, 3, 4, 5],
                            "Frontón" : [0, 1, 2, 3, 4, 5],
                            "Natación" : [0, 1, 2, 3, 4, 5],
                            "Tenis de mesa" : [0, 1, 2, 3, 4, 5],
                            "Tenis" : [0, 1, 2, 3, 4, 5],
                            "Ajedrez" : [0, 1, 2, 3, 4, 5],
                            "Motociclismo" : [0, 1, 2, 3, 4, 5],
                            "Petanca" : [0, 1, 2, 3, 4, 5],
                            "Caza" : [0, 1, 2, 3, 4, 5],
                            "Yoga / Pilates" : [0, 1, 2, 3, 4, 5],
                            "Baloncesto" : [0, 1, 2, 3, 4, 5],
                            "Pesca" : [0, 1, 2, 3, 4, 5],
                            "Ciclismo" : [0, 1, 2, 3, 4, 5],
                            "Crossfit" : [0, 1, 2, 3, 4, 5],
                            # películas (19 variables):
                            "Acción" : [0, 1, 2, 3, 4, 5],
                            "Aventura" : [0, 1, 2, 3, 4, 5],
                            "Animación" : [0, 1, 2, 3, 4, 5],
                            "Comedia" : [0, 1, 2, 3, 4, 5],
                            "Documental" : [0, 1, 2, 3, 4, 5],
                            "Drama" : [0, 1, 2, 3, 4, 5],
                            "Crimen" : [0, 1, 2, 3, 4, 5],
                            "Cine negro" : [0, 1, 2, 3, 4, 5],
                            "Fantasía" : [0, 1, 2, 3, 4, 5],
                            "Historia" : [0, 1, 2, 3, 4, 5],
                            "Terror" : [0, 1, 2, 3, 4, 5],
                            "Misterio" : [0, 1, 2, 3, 4, 5],
                            "Política" : [0, 1, 2, 3, 4, 5],
                            "Romántica" : [0, 1, 2, 3, 4, 5],
                            "Ciencia Ficción" : [0, 1, 2, 3, 4, 5],
                            "Suspense" : [0, 1, 2, 3, 4, 5],
                            "Musical" : [0, 1, 2, 3, 4, 5],
                            "Bélico" : [0, 1, 2, 3, 4, 5],
                            "Western" : [0, 1, 2, 3, 4, 5],
                            # aficiones (85 variables):
                            # actividades al aire libre (4 variables)
                            "Actividades en la playa" : [0, 1, 2, 3, 4, 5],
                            "Observación de aves" : [0, 1, 2, 3, 4, 5],
                            "Jardinería" : [0, 1, 2, 3, 4, 5],
                            "Montañismo" : [0, 1, 2, 3, 4, 5],
                            # DIY (15 variables)
                            "Manualidades" : [0, 1, 2, 3, 4, 5],
                            "Artesanías" : [0, 1, 2, 3, 4, 5],
                            "Tejido" : [0, 1, 2, 3, 4, 5],
                            "Croché" : [0, 1, 2, 3, 4, 5],
                            "Ganchillo" : [0, 1, 2, 3, 4, 5],
                            "Macramé" : [0, 1, 2, 3, 4, 5],
                            "Bordado" : [0, 1, 2, 3, 4, 5],
                            "Punto de cruz" : [0, 1, 2, 3, 4, 5],
                            "Bolillo" : [0, 1, 2, 3, 4, 5],
                            "Cerámica" : [0, 1, 2, 3, 4, 5],
                            "Modelismo" : [0, 1, 2, 3, 4, 5],
                            "Carpintería" : [0, 1, 2, 3, 4, 5],
                            "Costura" : [0, 1, 2, 3, 4, 5],
                            "Bricolage" : [0, 1, 2, 3, 4, 5],
                            "Robótica" : [0, 1, 2, 3, 4, 5],
                            # cocina (8 variables)
                            "Cerveza artesanal" : [0, 1, 2, 3, 4, 5],
                            "Cocina" : [0, 1, 2, 3, 4, 5],
                            "Repostería" : [0, 1, 2, 3, 4, 5],
                            "Gastronomía molecular" : [0, 1, 2, 3, 4, 5],
                            "Cocina india" : [0, 1, 2, 3, 4, 5],
                            "Cocina oriental" : [0, 1, 2, 3, 4, 5],
                            "Cocina mexicana" : [0, 1, 2, 3, 4, 5],
                            "Cocina mediterránea" : [0, 1, 2, 3, 4, 5],
                            # artes (18 variables)
                            "Museos" : [0, 1, 2, 3, 4, 5],
                            "Escritura" : [0, 1, 2, 3, 4, 5],
                            "Beatboxing" : [0, 1, 2, 3, 4, 5],
                            "Componer música" : [0, 1, 2, 3, 4, 5],
                            "Baile" : [0, 1, 2, 3, 4, 5],
                            "Fotografía" : [0, 1, 2, 3, 4, 5],
                            "Dibujo" : [0, 1, 2, 3, 4, 5],
                            "Instrumentos musicales" : [0, 1, 2, 3, 4, 5],
                            "Canto" : [0, 1, 2, 3, 4, 5],
                            "Conciertos" : [0, 1, 2, 3, 4, 5],
                            "Teatro" : [0, 1, 2, 3, 4, 5],
                            "Ópera" : [0, 1, 2, 3, 4, 5],
                            "Pintura" : [0, 1, 2, 3, 4, 5],
                            "Literatura" : [0, 1, 2, 3, 4, 5],
                            "Poesía" : [0, 1, 2, 3, 4, 5],
                            "Cómics" : [0, 1, 2, 3, 4, 5],
                            "Blogging" : [0, 1, 2, 3, 4, 5],
                            "Cine" : [0, 1, 2, 3, 4, 5],
                            # entretenimiento (11 variables)
                            "Juegos de mesa" : [0, 1, 2, 3, 4, 5],
                            "Dardos" : [0, 1, 2, 3, 4, 5],
                            "Crucigramas" : [0, 1, 2, 3, 4, 5],
                            "Juegos de cartas" : [0, 1, 2, 3, 4, 5],
                            "Rompecabezas" : [0, 1, 2, 3, 4, 5],
                            "Póker" : [0, 1, 2, 3, 4, 5],
                            "Videojuegos" : [0, 1, 2, 3, 4, 5],
                            "Bingo" : [0, 1, 2, 3, 4, 5],
                            "Casino" : [0, 1, 2, 3, 4, 5],
                            "Magia" : [0, 1, 2, 3, 4, 5],
                            "Telenovelas" : [0, 1, 2, 3, 4, 5],
                            # sociedad (9 variables)
                            "Reciclaje" : [0, 1, 2, 3, 4, 5],
                            "Actividades de la Iglesia" : [0, 1, 2, 3, 4, 5],
                            "Socializar" : [0, 1, 2, 3, 4, 5],
                            "Voluntariado" : [0, 1, 2, 3, 4, 5],
                            "Animales" : [0, 1, 2, 3, 4, 5],
                            "Astrología" : [0, 1, 2, 3, 4, 5],
                            "Tarot" : [0, 1, 2, 3, 4, 5],
                            "Meditación" : [0, 1, 2, 3, 4, 5],
                            "Prensa del corazón" : [0, 1, 2, 3, 4, 5],
                            # actividades grupales (9 variables)
                            "Viajar" : [0, 1, 2, 3, 4, 5],
                            "Cata de vino" : [0, 1, 2, 3, 4, 5],
                            "Cosplay" : [0, 1, 2, 3, 4, 5],
                            "Disfraces" : [0, 1, 2, 3, 4, 5],
                            "Turismo local" : [0, 1, 2, 3, 4, 5],
                            "Juegos de rol" : [0, 1, 2, 3, 4, 5],
                            "Rol en vivo" : [0, 1, 2, 3, 4, 5],
                            "Recreación histórica" : [0, 1, 2, 3, 4, 5],
                            "Club de fumadores" : [0, 1, 2, 3, 4, 5],
                            # coleccionismo (3 variables)
                            "Antigüedades" : [0, 1, 2, 3, 4, 5],
                            "Filatelia" : [0, 1, 2, 3, 4, 5],
                            "Numismática" : [0, 1, 2, 3, 4, 5],
                            # ciencias (8 variables)
                            "Astronomía" : [0, 1, 2, 3, 4, 5],
                            "Historia" : [0, 1, 2, 3, 4, 5],
                            "Matemáticas" : [0, 1, 2, 3, 4, 5],
                            "Física" : [0, 1, 2, 3, 4, 5],
                            "Química" : [0, 1, 2, 3, 4, 5],
                            "Filología" : [0, 1, 2, 3, 4, 5],
                            "Biología" : [0, 1, 2, 3, 4, 5],
                            "Zoología" : [0, 1, 2, 3, 4, 5],
                            # -- hasta aquí carácter, música, deportes, películas y aficiones (180 variables)
                            "Carnet de conducir usuario" : [0, 1], # 0=no 1=si
                            "Zona preferida" : ["Interior", "Ciudad", "Costa", "Montaña"],
                            "Ubicacion coliving" : ["Andalucía", "Aragón", "Principado de Asturias", "Islas Baleares", "Canarias", "Cantabria",
                                                  "Castilla y León", "Castilla-La Mancha", "Cataluña", "Comunidad Valenciana", "Extremadura", "Galicia",
                                                  "Comunidad de Madrid", "Región de Murcia", "Navarra", "País Vasco", "La Rioja", "Ceuta", "Melilla"],
                            "Instalaciones" : ["Sala de cine", "Sala de recreativos", "Sala de manualidades", "Gimnasio", "Sala de rehabilitación",
                                                "Pista de pádel", "Pista de tenis", "Piscina", "Piscina cubierta", "Campo de fútbol", "Campo de golf", "Spa",
                                                "Hípica", "Esquí", "Mesa de ping pong", "Mesa billar", "Futbolín", "Cancha de baloncesto", "Zonas verdes",
                                                "Huerto", "Zona de barbacoa", "Trastero", "Plaza de garaje", "Cocina", "Buffet", "Lavavajillas", "Lavandería"],
                            "Rango de edad que busca" : int, 
                            "Dinero a gastar" : int,
                            "Metros cuadrador que busca" : int,
                            "Baño" : [0, 1], # 0=privado 1=compartido,
                            "Zonas exteriores privadas" : [0, 1, 2], # 0=No 1=Jardín 2=Terraza
                            "Pertenencia a coliving": [0, 1], # 0=no 1=si
                            "Coliving ID" : int, # entiendo que no afecta al recomendador
}

# %%
# carácter

['Activo', 'Calmado', 'Atento', 'Alegre', 'Colaborador', 'Creativo', 'Decidido', 'De trato fácil', 
'Empático', 'Entusiasta', 'Flexible', 'Amable', 'Divertido', 'Honesto', 'Gracioso', 'Optimista', 'Ordenado', 
'Apasionado', 'Práctico', 'Proactivo', 'Sensato', 'Relajado', 'Sociable', 'Generoso']

# %%
# música

['Música alternativa','Blues','Clásica','Electrónica','Folk','Gospel','Instrumental','Jazz','Latina',
'Lounge','Metal','Ópera','Pop','Punk','R&B','Reggae','Rock','Soul','Copla','Pachangueo','Ye-yé','Bolero','Zarzuela','Flamenco']

# %%
# deportes

['Badminton','Jugar a los bolos','Boxeo','Béisbol','Piragüismo','Buceo','Fútbol','Golf', 'Excursionismo','Gimnasio',
'Montar a caballo','Pádel','Remo','Correr','Esquí','Frontón','Natación','Tenis de mesa','Tenis','Ajedrez','Motociclismo',
'Petanca','Caza','Yoga','Baloncesto','Pesca', 'Ciclismo', 'Crossfit']

# %%
# películas

['Acción','Aventura','Animación','Comedia','Documental','Drama','Crimen','Cine negro','Fantasía','Historia',
'Terror','Misterio','Política','Romántica','Ciencia Ficción','Suspense','Musical','Bélico','Western']

# %%
# aficiones 

['Actividades en la playa','Observación de aves','Jardinería','Montañismo','Manualidades','Artesanías','Tejido',
'Croché','Ganchillo','Macramé','Bordado','Punto de cruz','Bolillo','Cerámica','Modelismo','Carpintería','Costura',
'Bricolage','Robótica','Cerveza artesanal','Cocina','Repostería','Gastronomía molecular','Cocina india','Cocina oriental',
'Cocina mexicana','Cocina mediterránea','Museos','Escritura','Beatboxing','Componer música','Baile','Fotografía','Dibujo',
'Instrumentos musicales','Canto','Conciertos','Teatro','Ópera','Pintura','Literatura','Poesía','Cómics','Blogging','Cine',
'Juegos de mesa','Dardos','Crucigramas','Juegos de cartas','Rompecabezas','Póker','Videojuegos','Bingo','Casino','Magia',
'Telenovelas','Reciclaje','Actividades de la Iglesia','Socializar','Voluntariado','Animales','Astrología','Tarot','Meditación',
'Prensa del corazón','Viajar','Cata de vino','Cosplay','Disfraces','Turismo local','Juegos de rol','Rol en vivo','Recreación histórica',
'Club de fumadores','Antigüedades','Filatelia','Numismática','Astronomía','Historia','Matemáticas','Física','Química','Filología','Biología','Zoología']
