# %%
# IMPORTS
import numpy as np
import pandas as pd

from faker import Faker

# %%
# FUNCS
# For quick empty list assignment
def mklist(n):
    for i in range(n):
        yield []
        
# To easily add every data to the correct list
def item_to_lists(item, lists):
    for i in range(len(item)):
        lists[i].append(item[i])
        
    return lists

# To easily add every data to the correct list
def dict_to_lists(item, names, lists):
    for name, empty_list in zip(names, lists):
        if name in item.keys():
            empty_list.append(item.get(name))
            
        elif name not in item.keys():
            empty_list.append(0)
            
    return None

# %%
# To generate a fake user
def generate_fake_user(min_age, max_age):
    # Nacionalidad --------------> [FINALIZADO]
    nations_list = ['es_ES', 'es_CA',
                    'pt_PT', 'en_GB',
                    'fr_FR', 'de_DE',
                    'it_IT', 'nl_NL']
    u_nation = np.random.choice(nations_list, p=[0.58, 0.12, 0.04, 0.06, 0.04, 0.08, 0.03, 0.05])
    
    # Género --------------> [FINALIZADO]
    genders = ['hombre', 'mujer', 'otro']
    u_gender = np.random.choice(genders, p=[0.425, 0.525, 0.05])
    
    # Nombre e inicial --------------> [FINALIZADO]
    if u_gender == 'hombre':
        u_name = fk[u_nation].first_name_male()
    if u_gender == 'mujer':
        u_name = fk[u_nation].first_name_female()
    if u_gender == 'otro':
        u_name = fk[u_nation].first_name_nonbinary()
    
    u_last_name = fk[u_nation].last_name()
    
    # Idiomas --------------> [FINALIZADO]
    if u_nation == 'es_ES':
        u_lang = np.random.choice(['castellano', 'euskera', 'gallego'], p=[0.85, 0.10, 0.05])
        u_last_name_2 = fk[u_nation].last_name()
    elif u_nation == 'es_CA':
        u_lang = np.random.choice(['catalan', 'valenciano'], p=[0.6, 0.4])
        u_last_name_2 = fk[u_nation].last_name()
    elif u_nation == 'pt_PT':
        u_lang = np.random.choice(['castellano', 'gallego'], p=[0.60, 0.40])
        u_last_name_2 = fk[u_nation].last_name()
    elif u_nation == 'en_GB':
        u_lang = np.random.choice(['ingles', 'coreano', 'chino', 'japones'], p=[0.90, 0.02, 0.05, 0.03])
        u_last_name_2 = ''
    elif u_nation == 'fr_FR':
        u_lang = 'frances'
        u_last_name_2 = ''
    elif u_nation == 'de_DE':
        u_lang = np.random.choice(['aleman', 'ruso'], p=[0.95, 0.05])
        u_last_name_2 = ''
    elif u_nation == 'it_IT':
        u_lang = 'italiano'
        u_last_name_2 = ''
    else:
        u_lang = 'neerlandes'
        u_last_name_2 = ''
        
    u_full_last_name = f'{u_last_name} {u_last_name_2}'
    u_full_last_name = " ".join(u_full_last_name.split())
    
    
    # Mail --------------> [FINALIZADO]
    u_mail_company = fk.ascii_free_email()
    mail_version = np.random.choice(["1", "2", "3", "4"], p=[0.60, 0.25, 0.10, 0.05])
    u_name_2 = u_name
    if " " in u_name_2:
        u_name_2 = u_name_2.replace(" ", "")
    if mail_version == "1":
        u_mail = u_name_2.lower() + '_' + u_last_name.lower() + '@' + u_mail_company.split('@')[1]
    elif mail_version == "2":
        u_mail = u_last_name.lower() + u_name_2 + '@' + u_mail_company.split('@')[1]
    elif mail_version == "3":
        u_mail = u_name_2[0] + u_last_name.lower() + '@' + u_mail_company.split('@')[1]
    elif mail_version == "4":
        u_mail = u_name_2[0] + "_" + u_last_name[0] + "_" + u_last_name_2.lower() + '@' + u_mail_company.split('@')[1]
    
    # Dirección --------------> [FINALIZADO]
    u_direc = fk['es_ES'].street_address()
    
    # Provincia y CCAA --------------> [FINALIZADO]
    country = {'andalucia': ['Almería', 'Cádiz', 'Córdoba', 'Granada', 'Huelva', 'Jaén', 'Málaga', 'Sevilla'],
               'aragon': ['Huesca', 'Teruel', 'Zaragoza'],
               'asturias': ['Asturias'],
               'baleares': ['Islas Baleares'],
               'canarias': ['Las Palmas', 'Santa Cruz de Tenerife'],
               'cantabria': ['Cantabria'],
               'castillaleon': ['Ávila', 'Burgos', 'León', 'Palencia', 'Salamanca', 'Segovia', 'Soria', 'Valladolid', 'Zamora'],
               'castillalamancha': ['Albacete', 'Ciudad Real', 'Cuenca', 'Guadalajara', 'Toledo'],
               'cataluña': ['Barcelona', 'Gerona', 'Lérida', 'Tarragona'],
               'valencia': ['Alicante', 'Castellón', 'Valencia'],
               'extremadura': ['Badajoz', 'Cáceres'],
               'galicia': ['La Coruña', 'Lugo', 'Orense', 'Pontevedra'],
               'madrid': ['Madrid'],
               'murcia': ['Murcia'],
               'navarra': ['Navarra'],
               'paisvasco': ['Álava', 'Vizcaya', 'Guipúzcoa'],
               'rioja': ['La Rioja'],
               'ceuta': ['Ceuta'],
               'melilla': ['Melilla']}
    
    zipcode = {'Almería': '04', 'Cádiz': '11', 'Córdoba': '14', 'Granada': '18', 'Huelva': '21', 'Jaén': '23', 'Málaga': '29', 'Sevilla': '41', 
               'Huesca': '22', 'Teruel': '44', 'Zaragoza': '50', 
               'Asturias': '33', 
               'Islas Baleares': '07', 
               'Las Palmas': '35', 'Santa Cruz de Tenerife': '38', 
               'Cantabria': '39', 
               'Ávila': '50', 'Burgos': '09', 'León': '24', 'Palencia': '34', 'Salamanca': '37', 'Segovia': '40', 'Soria': '42', 'Valladolid': '47', 'Zamora': '49', 
               'Albacete': '02', 'Ciudad Real': '13', 'Cuenca': '16', 'Guadalajara': '19', 'Toledo': '45', 
               'Barcelona': '08', 'Gerona': '17', 'Lérida': '25', 'Tarragona': '43', 
               'Alicante': '03', 'Castellón': '12', 'Valencia': '46', 
               'Badajoz': '06', 'Cáceres': '10', 
               'La Coruña': '15', 'Lugo': '27', 'Orense': '32', 'Pontevedra': '36', 
               'Madrid': '28', 
               'Murcia': '30', 
               'Navarra': '31', 
               'Álava': '01', 'Vizcaya': '48', 'Guipúzcoa': '20', 
               'La Rioja': '26', 
               'Ceuta': '51', 
               'Melilla': '52'}

    u_ccaa = np.random.choice(list(country.keys()))
    u_prov = np.random.choice(country[u_ccaa])
    # Código Postal --------------> [FINALIZADO]
    u_zipc = zipcode.get(u_prov) + str(np.random.randint(9)) + str(np.random.randint(9)) + str(np.random.randint(9))
    
    # Teléfono --------------> [FINALIZADO]
    u_phone = str(fk['es_ES'].phone_number()).replace(' ', '')
    
    # Id
    # Generada desde fuera de la función
    
    ##########
    # FIN DE DATOS GENERALES
    # u_name
    # u_full_name
    # u_mail
    # u_direc
    # u_prov
    # u_zipc
    # u_phone
    # u_id (generada fuera)
    ##########
    
    # Aficiones --------------> [FINALIZADO]
    hobbies = ['accion', 'activo', 'ajedrez', 'alegre', 'alternativa',
               'amable', 'animales', 'antiguedades', 'apasionado', 'arte',
               'artesanias', 'astrologia', 'astronomia', 'atento', 'aventura',
               'aventurero', 'aves', 'badminton', 'bailarin', 'baile',
               'baloncesto', 'beatboxing', 'beisbol', 'belico', 'bingo',
               'biologia', 'blogging', 'blues', 'bolero', 'bolillo',
               'bolos', 'bordado', 'boxeo', 'bricolage', 'buceo',
               'calmado', 'cantante', 'canto', 'carpinteria', 'cartas',
               'casino', 'caza', 'ceramica', 'cerveza', 'ciclismo',
               'cienciaficcion', 'cine', 'cinefilo', 'clasica', 'cocina',
               'colaborador', 'comedia', 'comics', 'comprador', 'conciertos',
               'copla', 'corazon', 'correr', 'cosplay', 'costura',
               'creativo', 'crimen', 'croche', 'crossfit', 'crucigramas',
               'cultura', 'dardos', 'decidido', 'deportista', 'dibujo',
               'disfraces', 'divertido', 'documental', 'drama', 'electronica',
               'empatico', 'emprendedor', 'entustiasta', 'escritura', 'esqui',
               'excursionismo', 'excursionista', 'familiar', 'fantasia', 'fiestero',
               'filatelia', 'filologia', 'fisica', 'flamenco', 'flexible',
               'folk', 'foodie', 'fotografia', 'fotografo', 'fronton',
               'fumadores', 'futbol', 'gamer', 'ganchillo', 'gastronomia',
               'generoso', 'gimnasio', 'golf', 'gospel', 'gracioso',
               'hipica', 'historia', 'historicas', 'hogar', 'honesto',
               'iglesia', 'india', 'instrumental', 'instrumentos', 'jardineria',
               'jazz', 'latina', 'libros', 'literatura', 'lounge',
               'macrame', 'madrugador', 'magia', 'manualidades', 'matematicas',
               'meditacion', 'mediterranea', 'mesa', 'metal', 'mexicana', 
               'misterio', 'moda', 'modelismo', 'montanismo', 'motociclismo',
               'museos', 'musica', 'musical', 'natacion', 'negro',
               'nocturno', 'numismatica', 'opera', 'optimista', 'ordenado',
               'oriental', 'pachangueo', 'padel', 'pesca', 'petanca',
               'pintura', 'piraguismo', 'playa', 'poesia', 'poker',
               'politica', 'practico', 'proactivo', 'punk', 'puntocruz',
               'quimica', 'rb', 'reciclaje', 'reggae', 'relajado',
               'remo', 'reposteria', 'robotica', 'rock', 'rol',
               'romantica', 'rompecabezas', 'saludable', 'sensato', 'sociable',
               'socializar', 'soul', 'suspense', 'tarot', 'teatro',
               'tecnologia', 'tejido', 'telenovelas', 'tenis', 'tenismesa',
               'terror', 'trabajo', 'tratofacil', 'turismo', 'vegano',
               'vegetariano', 'viajar', 'viajero', 'videojuegos', 'vino',
               'vivo', 'voluntariado', 'western', 'yeye', 'yoga',
               'zarzuela', 'zoologia']
    
    hobbies_num = np.random.randint(15, (len(hobbies)/2)+1)
    hobbies = list(np.random.choice(hobbies, hobbies_num, replace=False))
    hobbies_values = list(np.random.choice([2, 4], size=hobbies_num))

    u_hobbies = {k:v for k, v in zip(hobbies, hobbies_values)}
    
    
    # u_full_last_name
    
    
    # Carnet de conducir --------------> [HECHO]
    #Generado después de "edad"

    
    
    # u_prov
    
    # u_zipc
    
    # Presupuesto --------------> [HECHO]
    price_list = [300, 400, 500,
                  600, 700,
                  800, 900, 1000, 1100,
                  1200, 1300, 1400, 1500]
    
    u_budget = np.random.choice(price_list, p=[0.1, 0.1, 0.1,
                                               0.15, 0.15,
                                               0.05, 0.05, 0.05, 0.05,
                                               0.05, 0.05, 0.05, 0.05])
    
    
    # u_direc
    
    
    # Age --------------> [FINALIZADO]
    u_years = np.random.gamma(3, 6)
    u_years_pron = np.random.randint (1, 999)
    while u_years < 60 or u_years > 100:
        u_years = np.random.gamma(3, 6)
        u_years_pron = np.random.randint (1, 999)
    if u_years_pron == 3:
        u_years = np.random.randint (100, 103)
        
    u_years = int(u_years)

    
    # Carnet de conducir --------------> [FINALIZADO]
    license = [False, True]
    if u_gender == "mujer" and u_years >= 80:
        u_drive = np.random.choice(license, p=[0.95, 0.05])
    else:
        u_drive = np.random.choice(license, p=[0.25, 0.75])
    
    
    
    # u_mail
    
    
    # Zonas exteriores --------------> [FINALIZADO]
    negative_choice = fk.boolean(chance_of_getting_true=75)
    
    if negative_choice == False:
        u_outs = ['no']
    
    else:
        outside = ['jardin', 'terraza', 'baloncesto', 'huerto', 'barbacoa', 'padel',
                   'tenis', 'piscina', 'cubierta', 'futbol', 'golf', 'hipica', 'esqui']
        choices = np.random.randint(1, len(outside)+1)
        u_outs = np.random.choice(outside, size=choices, replace=False)
    
    
    # Fumador --------------> [FINALIZADO]
    smoker = [False, True]
    u_smoke = np.random.choice(smoker, p=[0.5, 0.5])
    
    
    # u_gender
    
    
    # Miembros unidad familiar       #<------------elegir un numero entre 1-10
    group = ['individual', 'grupo', 'familia']
    u_family = np.random.choice(group)
    
    
    # Id
    
    
    # u_lang
    
    
    # Instalaciones --------------> [FINALIZADO]
    negative_choice = fk.boolean(chance_of_getting_true=90)
    
    if negative_choice == False:
        u_facil = []
        
    else:
        facilities = ['salacine', 'recreativos', 'salamanualidades',
                      'gimnasio', 'rehabilitacion', 'pingpong',
                      'spa', 'billar', 'futbolin', 'trastero',
                      'garage', 'cocina', 'buffet', 'lavavajillas', 'lavanderia']
            
        choices = np.random.randint(1, len(facilities)+1)
        u_facil = np.random.choice(facilities, size=choices, replace=False)
        
    
    # Aseo --------------> [FINALIZADO]
    washroom = ['compartido', 'privado']
    u_bath = np.random.choice(washroom, p=[0.35, 0.65])
    
    
    
    # Mascotas --------------> [FINALIZADO]
    pets = [False, True]
    u_pets = np.random.choice(pets, p=[0.6, 0.4])
    
    
    # Superficie --------------> [HECHO]  <--------------Se cambiaron los números de str a int
    size = [50, 100, 150, 200, 250, 300, 350, 400, 450, 500,
            550, 600, 650, 700, 750, 800, 850, 900, 950, 1000]
    u_sqr_m = np.random.choice(size)
    
    
    # u_name
    
        
    # Sector --------------> [FINALIZADO]
    sector = ['sanidad', 'ingenieria', 'forestal', 'administrativo', 'artes', 'comunicacion', 'derecho',
              'empresariales', 'enseñanza', 'investigacioncientifica', 'investigaciontecnica', 'musica',
              'seguridad', 'rh', 'cine', 'amacasa', 'mantenimiento', 'construccion', 'otro']
    u_sector = np.random.choice(sector)
    
    
    # Colectivo LGTB --------------> [FINALIZADO]
    orientation = [False, True]
    u_lgtb = np.random.choice(orientation, p=[0.65, 0.35])
    
    
    # Política --------------> [FINALIZADO]
    politic = [False, True]
    u_politic = np.random.choice(politic, p=[0.6, 0.4])
    
    
    # Rango edad para compartir q busca --------------> [FINALIZADO]
    age_range = ['50-60', '60-70', '70-80', '+80']
    u_range = np.random.choice(age_range)
    
    
    # u_ccaa
    
    
    # Religión --------------> [FINALIZADO]
    religion = [False, True]
    u_relig = np.random.choice(religion, p=[0.6, 0.4])
    
    
    # u_phone
    
    
    #TIPO VIVIENDA --------------> [FINALIZADO]
    house = ['piso', 'unifamiliar', 'atico', 'duplex', 'chalet', 'otros']
    u_house = np.random.choice(house)
    
    
    # Entorno --------------> [FINALIZADO]
    locations = ['interior', 'ciudad', 'costa', 'montaña']      # TODO
    u_env = np.random.choice(locations)

    
    # Unificación de características del usuario
    #user = [u_name, u_full_last_name, u_mail, u_direc, u_prov,
    #        u_zipc, u_phone, u_drive, u_budget, u_years,
    #        u_outs, u_smoke, u_gender, u_family, u_lang,
    #        u_facil, u_bath, u_pets, u_sqr_m, u_sector,
    #        u_lgtb, u_politic, u_range, u_ccaa, u_relig,
    #        u_house, u_env]
    
    user = [u_years, u_gender, u_sector, u_lang, u_lgtb,
            u_relig, u_politic, u_pets, u_smoke, u_drive,
            u_env, u_house, u_prov, u_facil, u_range,
            u_budget, u_sqr_m, u_bath, u_outs, u_family]
            
    
    
    return user, u_hobbies

# %%
# Instance faker object
locale_dict = ['es_ES',
               'es_CA',
               'pt_PT',
               'en_GB',
               'fr_FR',
               'de_DE',
               'it_IT',
               'nl_NL']

fk = Faker(locale_dict)

# %%
# Build aux objects
# Empty lists

#nombre, apellidos, email, direccion, ciudad = mklist(5)
#cp, telefono, carnet, dinero, edad = mklist(5)
#exteriores, fumador, genero, gente, idiomas = mklist(5)
#instalaciones, lavabo, mascotas, metros, oficio = mklist(5)
#orientacionSexual, politica, rangoEdad, region, religion = mklist(5)
#tipoVivienda, ubicacion = mklist(2)

edad, genero, oficio, idiomas, orientacionSexual = mklist(5)
religion, politica, mascotas, fumador, carnet = mklist(5)
ubicacion, tipoVivienda, region, instalaciones, rangoEdad = mklist(5)
dinero, metros, lavabo, exteriores, gente = mklist(5)
id_usuario = []


# List of lists
#user_lists = [nombre, apellidos, email, direccion, ciudad,
#              cp, telefono, carnet, dinero, edad,
#              exteriores, fumador, genero, gente, idiomas,
#              instalaciones, lavabo, mascotas, metros, oficio,
#              orientacionSexual, politica, rangoEdad, region, religion,
#              tipoVivienda, ubicacion]

user_lists = [edad, genero, oficio, idiomas, orientacionSexual,
              religion, politica, mascotas, fumador, carnet,
              ubicacion, tipoVivienda, region, instalaciones, rangoEdad,
              dinero, metros, lavabo, exteriores, gente]

# Empty lists
activo, deportista, calmado, atento = mklist(4)
alegre, colaborador, creativo, decidido, tratofacil = mklist(5)
empatico, entusiasta, flexible, amable, divertido = mklist(5)
honesto, gracioso, optimista, ordenado, apasionado = mklist(5)
practico, proactivo, sensato, relajado, generoso = mklist(5)
alternativa, blues, clasica, electronica, folk = mklist(5)
gospel, instrumental, jazz, latina, lounge = mklist(5)
metal, opera, punk, rb, reggae = mklist(5)
rock, soul, copla, pachangueo, yeye = mklist(5)
bolero, zarzuela, flamenco, accion, aventura = mklist(5)
comedia, documental, drama, crimen, negro = mklist(5)
fantasia, historicas, terror, misterio, politica = mklist(5)
romantica, cienciaficcion, suspense, musical, belico = mklist(5)
western, badminton, beisbol, boxeo, baloncesto = mklist(5)
bolos, Piraguismo, buceo, futbol, crossfit = mklist(5)
ciclismo, golf, gimnasio, excursionismo, hipica = mklist(5)
padel, remo, correr, esqui, fronton = mklist(5)
natacion, tenismesa, tenis, ajedrez, motociclismo = mklist(5)
petanca, caza, yoga, pesca, playa = mklist(5)
aves, jardineria, montanismo, manualidades, artesanias = mklist(5)
tejido, croche, ganchillo, macrame, bordado = mklist(5)
puntocruz, bolillo, ceramica, modelismo, carpinteria = mklist(5)
costura, bricolaje, robotica, cerveza, cocina = mklist(5)
reposteria, gastronomia, india, oriental, mexicana = mklist(5)
mediterranea, museos, escritura, beatboxing, componermusica = mklist(5)
baile, fotografia, dibujo, instrumentos, canto = mklist(5)
conciertos, teatro, pintura, literatura, poesia = mklist(5)
comics, blogging, cine, mesa, dardos = mklist(5)
crucigramas, cartas, rompecabezas, poker, videojuegos = mklist(5)
bingo, casino, magia, telenovelas, reciclaje = mklist(5)
iglesia, socializar, voluntariado, animales, astrologia = mklist(5)
tarot, meditacion, corazon, viajar, vino = mklist(5)
cosplay, disfraces, turismo, rol, vivo = mklist(5)
historica, fumadores, antiguedades, filatelia, numismatica = mklist(5)
astronomia, historia, matematicas, fisica, quimica = mklist(5)
filologia, biologia, zoologia = mklist(3)




# List of lists
hobbies_lists = [activo, deportista, calmado, atento,
                 alegre, colaborador, creativo, decidido, tratofacil,
                 empatico, entusiasta, flexible, amable, divertido,
                 honesto, gracioso, optimista, ordenado, apasionado,
                 practico, proactivo, sensato, relajado, generoso,
                 alternativa, blues, clasica, electronica, folk,
                 gospel, instrumental, jazz, latina, lounge,
                 metal, opera, punk, rb, reggae,
                 rock, soul, copla, pachangueo, yeye,
                 bolero, zarzuela, flamenco, accion, aventura,
                 comedia, documental, drama, crimen, negro,
                 fantasia, historicas, terror, misterio, politica,
                 romantica, cienciaficcion, suspense, musical, belico,
                 western, badminton, beisbol, boxeo, baloncesto,
                 bolos, Piraguismo, buceo, futbol, crossfit,
                 ciclismo, golf, gimnasio, excursionismo, hipica,
                 padel, remo, correr, esqui, fronton,
                 natacion, tenismesa, tenis, ajedrez, motociclismo,
                 petanca, caza, yoga, pesca, playa,
                 aves, jardineria, montanismo, manualidades, artesanias,
                 tejido, croche, ganchillo, macrame, bordado,
                 puntocruz, bolillo, ceramica, modelismo, carpinteria,
                 costura, bricolaje, robotica, cerveza, cocina,
                 reposteria, gastronomia, india, oriental, mexicana,
                 mediterranea, museos, escritura, beatboxing, componermusica,
                 baile, fotografia, dibujo, instrumentos, canto,
                 conciertos, teatro, pintura, literatura, poesia,
                 comics, blogging, cine, mesa, dardos,
                 crucigramas, cartas, rompecabezas, poker, videojuegos,
                 bingo, casino, magia, telenovelas, reciclaje,
                 iglesia, socializar, voluntariado, animales, astrologia,
                 tarot, meditacion, corazon, viajar, vino,
                 cosplay, disfraces, turismo, rol, vivo,
                 historica, fumadores, antiguedades, filatelia, numismatica,
                 astronomia, historia, matematicas, fisica, quimica,
                 filologia, biologia, zoologia]

# List of names
hobbies_names = ['activo', 'deportista', 'calmado', 'atento',
                 'alegre', 'colaborador', 'creativo', 'decidido', 'tratofacil',
                 'empatico', 'entusiasta', 'flexible', 'amable', 'divertido',
                 'honesto', 'gracioso', 'optimista', 'ordenado', 'apasionado',
                 'practico', 'proactivo', 'sensato', 'relajado', 'generoso',
                 'alternativa', 'blues', 'clasica', 'electronica', 'folk',
                 'gospel', 'instrumental', 'jazz', 'latina', 'lounge',
                 'metal', 'opera', 'punk', 'rb', 'reggae', 
                 'rock', 'soul', 'copla', 'pachangueo', 'yeye',
                 'bolero', 'zarzuela', 'flamenco', 'accion', 'aventura',
                 'comedia', 'documental', 'drama', 'crimen', 'negro',
                 'fantasia', 'historicas', 'terror', 'misterio', 'politica',
                 'romantica', 'cienciaficcion', 'suspense', 'musical', 'belico',
                 'western', 'badminton', 'beisbol', 'boxeo', 'baloncesto',
                 'bolos', 'Piraguismo', 'buceo', 'futbol', 'crossfit',
                 'ciclismo', 'golf', 'gimnasio', 'excursionismo', 'hipica',
                 'padel', 'remo', 'correr', 'esqui', 'fronton',
                 'natacion', 'tenismesa', 'tenis', 'ajedrez', 'motociclismo',
                 'petanca', 'caza', 'yoga', 'pesca', 'playa',
                 'aves', 'jardineria', 'montanismo', 'manualidades', 'artesanias',
                 'tejido', 'croche', 'ganchillo', 'macrame', 'bordado',
                 'puntocruz', 'bolillo', 'ceramica', 'modelismo', 'carpinteria',
                 'costura', 'bricolaje', 'robotica', 'cerveza', 'cocina',
                 'reposteria', 'gastronomia', 'india', 'oriental', 'mexicana',
                 'mediterranea', 'museos', 'escritura', 'beatboxing', 'componermusica',
                 'baile', 'fotografia', 'dibujo', 'instrumentos', 'canto',
                 'conciertos', 'teatro', 'pintura', 'literatura', 'poesia',
                 'comics', 'blogging', 'cine', 'mesa', 'dardos',
                 'crucigramas', 'cartas', 'rompecabezas', 'poker', 'videojuegos',
                 'bingo', 'casino', 'magia', 'telenovelas', 'reciclaje',
                 'iglesia', 'socializar', 'voluntariado', 'animales', 'astrologia',
                 'tarot', 'meditacion', 'corazon', 'viajar', 'vino',
                 'cosplay', 'disfraces', 'turismo', 'rol', 'vivo',
                 'historica', 'fumadores', 'antiguedades', 'filatelia', 'numismatica',
                 'astronomia', 'historia', 'matematicas', 'fisica', 'quimica',
                 'filologia', 'biologia', 'zoologia']

# %%
# Generate users
users_to_create = 10

for i in range(users_to_create):
    user, hobbies = generate_fake_user(60, 115)
    item_to_lists(user, user_lists)
    dict_to_lists(hobbies, hobbies_names, hobbies_lists)

# %%
# Create users_id list
id_usuario = [i for i in range(1, len(user_lists[-1])+1)]   #<---- _id

# %%
# Build aux objects
# List of lists
#users_lists = [nombre, apellidos, email, direccion, ciudad,
#               cp, telefono, id_usuario, carnet, dinero,
#               edad, exteriores, fumador, genero, gente,
#               idiomas, instalaciones, lavabo, mascotas, metros,
#               oficio, orientacionSexual, politica, rangoEdad, region,
#               religion, tipoVivienda, ubicacion]

users_lists = [edad, genero, oficio, idiomas, orientacionSexual,
              religion, politica, mascotas, fumador, carnet,
              ubicacion, tipoVivienda, region, instalaciones, rangoEdad,
              dinero, metros, lavabo, exteriores, gente,
              id_usuario]

# List of names
#users_names = ['nombre', 'apellidos', 'email', 'direccion', 'ciudad',
#               'cp', 'telefono', 'id_usuario', 'carnet', 'dinero',
#               'edad', 'exteriores', 'fumador', 'genero', 'gente',
#               'idiomas', 'instalaciones', 'lavabo', 'mascotas', 'metros',
#               'oficio', 'orientacionSexual', 'politica', 'rangoEdad', 'region',
#               'religion', 'tipoVivienda', 'ubicacion']

users_names = ['edad', 'genero', 'oficio', 'idiomas', 'orientacionSexual',
               'religion', 'politica', 'mascotas', 'fumador', 'carnet',
               'ubicacion', 'tipoVivienda', 'region', 'instalaciones', 'rangoEdad',
               'dinero', 'metros', 'lavabo', 'exteriores', 'gente',
               'id_usuario']

# %%
# Turn data into dataframe
fake_users = {k: v for k, v in zip(users_names, users_lists)}
fake_hobbies = {k: v for k, v in zip(hobbies_names, hobbies_lists)}

# %%
# Generate csv with python 3.8
fake_users.update(fake_hobbies)
fake_data = pd.DataFrame(fake_users)

# Generate csv with python 3.9
# fake_data = pd.DataFrame(fake_users | fake_hobbies)

# %%
# Show DataFrame to check for errors
fake_data
# Out:
#    edad  genero         oficio     idiomas  orientacionSexual  religion  \
# 0    75   mujer  empresariales     euskera              False     False
# 1    79    otro         musica  castellano              False      True
# 2    64  hombre  empresariales  neerlandes              False      True
# 3    62  hombre  empresariales  castellano              False      True
# 4    60   mujer  mantenimiento  castellano              False     False
# 5    64   mujer           otro      ingles               True     False
# 6    62   mujer   comunicacion  castellano              False     False
# 7    62   mujer        amacasa  castellano              False      True
# 8    69  hombre         musica  castellano              False     False
# 9    65   mujer       forestal  castellano              False      True
#
#    politica  mascotas  fumador  carnet  ... filatelia numismatica astronomia  \
# 0         2     False    False    True  ...         4           0          2
# ...

# %%
# Save dataframe as csv
fake_data.to_csv(f'./fake_users_{users_to_create}_users.csv', encoding='utf-8')

# Save dataframe as json
fake_data.to_json(f'./fake_users_{users_to_create}_users.json', orient='records')

# %% [markdown]
# ___
# # A PARTIR DE AQUI SON NOTAS DE FER Y MA

# %%
f'Hej! {None}'
# Out:
# 'Hej! None'

# %%
# {
#   "nombre": "Juan",
#   "apellidos": "Sanchez Rodriguez",
#   "email": "guillem@guillem.com",
#   "direccion": "Calle Mayor 48",
#   "ciudad": "Sevilla",
#   "cp": "28154",
#   "telefono": "611520515",
#   "id_usuario": 15
# }

# %%
{
  "aficiones": [
    "activo: 1",
    "deportista: 2",
    "calmado: 3",
    "atento: 4",
    "alegre: 5",
    "colaborador: 4",
    "creativo: 4",
    "decidido: 4",
    "tratofacil: 3",
    "empatico: 3",
    "entustiasta: 3",
    "flexible: 4",
    "amable: 4",
    "divertido: 4",
    "honesto: 4",
    "gracioso: 4",
    "optimista: 4",
    "ordenado: 4",
    "apasionado: 4",
    "practico: 5",
    "proactivo: 5",
    "sensato: 5",
    "relajado: 5",
    "sociable: 5",
    "generoso: 5",
    "alternativa: 5",
    "blues: 4",
    "clasica: 4",
    "electronica: 3",
    "folk: 4",
    "gospel: 3",
    "instrumental: 3",
    "jazz: 4",
    "latina: 3",
    "alternativa: 3",
    "blues: 4",
    "clasica: 4",
    "electronica: 3",
    "folk: 4",
    "gospel: 4",
    "instrumental: 3",
    "jazz: 4",
    "latina: 4",
    "lounge: 4",
    "metal: 4",
    "opera: 4",
    "punk: 4",
    "rb: 4",
    "reggae: 4",
    "rock: 5",
    "soul: 5",
    "copla: 5",
    "pachangueo: 4",
    "yeye: 5",
    "bolero: 5",
    "zarzuela: 5",
    "flamenco: 5",
    "accion: 5",
    "aventura: 5",
    "comedia: 4",
    "documental: 4",
    "drama: 4",
    "crimen: 4",
    "negro: 3",
    "fantasia: 4",
    "historia: 4",
    "terror: 4",
    "misterio: 4",
    "politica: 4",
    "romantica: 4",
    "cienciaficcion: 3",
    "suspense: 4",
    "musical: 4",
    "belico: 4",
    "western: 4",
    "badminton: 5",
    "beisbol: 5",
    "boxeo: 5",
    "baloncesto: 4",
    "bolos: 3",
    "piraguismo: 4",
    "buceo: 5",
    "futbol: 5",
    "crossfit: 5",
    "ciclismo: 5",
    "golf: 5",
    "gimnasio: 2",
    "excursionismo: 4",
    "hipica: 5",
    "padel: 5",
    "remo: 5",
    "correr: 4",
    "esqui: 4",
    "fronton: 3",
    "natacion: 3",
    "tenismesa: 2",
    "tenis: 3",
    "ajedrez: 3",
    "motociclismo: 2",
    "petanca: 3",
    "caza: 4",
    "yoga: 4",
    "pesca: 4",
    "playa: 1",
    "aves: 1",
    "jardineria: 3",
    "montanismo: 3",
    "manualidades: 3",
    "artesanias: 4",
    "tejido: 4",
    "croche: 4",
    "ganchillo: 4",
    "macrame: 4",
    "bordado: 4",
    "puntocruz: 3",
    "bolillo: 4",
    "ceramica: 4",
    "modelismo: 4",
    "carpinteria: 4",
    "costura: 4",
    "bricolage: 4",
    "robotica: 4",
    "cerveza: 2",
    "cocina: 4",
    "reposteria: 4",
    "gastronomia: 2",
    "india: 4",
    "oriental: 4",
    "mexicana: 4",
    "mediterranea: 4",
    "museos: 3",
    "escritura: 3",
    "beatboxing: 3",
    "componermusica: 2",
    "baile: 4",
    "fotografia: 4",
    "dibujo: 3",
    "instrumentos: 2",
    "canto: 5",
    "conciertos: 4",
    "teatro: 5",
    "opera: 5",
    "pintura: 5",
    "literatura: 5",
    "poesia: 4",
    "comics: 4",
    "blogging: 4",
    "cine: 5",
    "mesa: 2",
    "dardos: 4",
    "crucigramas: 3",
    "cartas: 3",
    "rompecabezas: 3",
    "poker: 4",
    "videojuegos: 3",
    "bingo: 4",
    "casino: 4",
    "magia: 4",
    "telenovelas: 3",
    "reciclaje: 3",
    "iglesia: 2",
    "socializar: 4",
    "voluntariado: 3",
    "animales: 4",
    "astrologia: 4",
    "tarot: 4",
    "meditacion: 4",
    "corazon: 3",
    "viajar: 3",
    "vino: 3",
    "cosplay: 4",
    "disfraces: 4",
    "turismo: 4",
    "rol: 3",
    "vivo: 5",
    "historica: 4",
    "fumadores: 4",
    "antiguedades: 3",
    "filatelia: 4",
    "numismatica: 4",
    "astronomia: 3",
    "historia: 4",
    "matematicas: 3",
    "fisica: 4",
    "quimica: 4",
    "filologia: 4",
    "biologia: 5",
    "zoologia: 5"
  ],
  "apellidos": "Sanchez Rodriguez",
  "carnet": true,
  "ciudad": "Sevilla",
  "cp": "28154",
  "dinero": "1300",
  "direccion": "Calle Mayor 48",
  "edad": 60,
  "email": "guillem@guillem.com",
  "exteriores": [
    "jardin",
    "no",
    "terraza",
    "baloncesto",
    "huerto",
    "barbacoa",
    "padel",
    "tenis",
    "piscina",
    "cubierta",
    "futbol",
    "golf",
    "hipica",
    "esqui"
  ],
  "fumador": true,
  "genero": "hombre",
  "gente": "4",
  "id_usuario": 15,
  "idiomas": [
    "castellano",
    "catalan",
    "euskera",
    "gallego",
    "valenciano",
    "coreano",
    "chino",
    "japones",
    "ingles",
    "italiano",
    "aleman",
    "frances",
    "ruso",
    "neerlandes"
  ],
  "instalaciones": [
    "salacine",
    "recreativos",
    "salamanualidades",
    "gimnasio",
    "rehabilitacion",
    "pingpong",
    "spa",
    "billar",
    "futbolin",
    "trastero",
    "garage",
    "cocina",
    "buffet",
    "lavavajillas",
    "lavanderia"
  ],
  "lavabo": "privado",
  "mascotas": false,
  "metros": "800",
  "nombre": "Juan",
  "oficio": [
    "sanidad",
    "ingenieria",
    "forestal",
    "administrativo",
    "artes",
    "comunicacion",
    "derecho",
    "empresariales",
    "enseñanza",
    "investigacioncientifica",
    "investigaciontecnica",
    "musica",
    "seguridad",
    "rh",
    "cine",
    "amacasa",
    "mantenimiento",
    "construccion",
    "otro"
  ],
  "orientacionSexual": false,
  "politica": true,
  "rangoEdad": [
    "50-60",
    "60-70",
    "70-80",
    "+80"
  ],
  "region": [
    "andalucia",
    "aragon",
    "asturias",
    "baleares",
    "canarias",
    "cantabria",
    "castillalamancha",
    "castillaleon",
    "cataluña",
    "valencia",
    "extremadura",
    "galicia",
    "madrid",
    "murcia",
    "navarra",
    "paisvasco",
    "rioja",
    "ceuta",
    "melilla"
  ],
  "religion": false,
  "telefono": "611520515",
  "tipoVivienda": "duplex",
  "ubicacion": "interior"
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11840/4113945084.py in <module>
#     191   ],
#     192   "apellidos": "Sanchez Rodriguez",
# --> 193   "carnet": true,
#     194   "ciudad": "Sevilla",
#     195   "cp": "28154",
#
# NameError: name 'true' is not defined
